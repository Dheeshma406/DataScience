# %% [markdown]
# ## Fitness Dataset

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# **1.Load the fitness dataset into a Pandas Dataframe.**

# %%
df=pd.read_csv("C:\\Users\\ABINANDH SREEKUMAR\\Downloads\\fitness_dataset_ml.csv")
df
# Out:
#        TotalSteps  Calories  SedentaryMinutes  LightlyActiveMinutes  \
# 0           13162      1985               728                   328
# 1           13162      1985               728                   328
# 2           13162      1985               728                   328
# 3           13162      1985               728                   328
# 4           13162      1985               728                   328
# ...           ...       ...               ...                   ...
# 12620        8064      1849               770                   137
# 12621        8064      1849               770                   137
# 12622        8064      1849               770                   137
# 12623        8064      1849               770                   137
# 12624        8064      1849               770                   137
#
#        FairlyActiveMinutes  VeryActiveMinutes  SedentaryActiveDistance  \
# 0                       13                 25                      0.0
# ...

# %% [markdown]
# **Observation:**
#
#  * Here the Fitness dataset will be loaded.In this dataset it shows 12625 rows and 18 columns
#
#    are present in it.

# %% [markdown]
# **2.Display the first 10 rows of the dataset.**

# %%
df.head(10)
# Out:
#    TotalSteps  Calories  SedentaryMinutes  LightlyActiveMinutes  \
# 0       13162      1985               728                   328
# 1       13162      1985               728                   328
# 2       13162      1985               728                   328
# 3       13162      1985               728                   328
# 4       13162      1985               728                   328
# 5       13162      1985               728                   328
# 6       13162      1985               728                   328
# 7       13162      1985               728                   328
# 8       13162      1985               728                   328
# 9       13162      1985               728                   328
#
#    FairlyActiveMinutes  VeryActiveMinutes  SedentaryActiveDistance  \
# 0                   13                 25                      0.0
# 1                   13                 25                      0.0
# ...

# %% [markdown]
# **Observation:**
#
#  * In this we use .head(10),it shows the first 10 rows in a dataset

# %% [markdown]
# **3.What is the shape of the dataset.**

# %%
df.shape
# Out:
# (12625, 18)

# %% [markdown]
# **Observation:**
#
#  * In this we use .shape,it shows how many rows and columns are present in the dataset.
#
#  * Here we have 12625 rows and 18 columns.

# %% [markdown]
# **4.Check for duplicate records.How many duplicates are present? Remove them.**

# %%
print(df.duplicated().value_counts())
# Out:
# False    12503
# True       122
# Name: count, dtype: int64

# %%
df=df.drop_duplicates()
df
# Out:
#        TotalSteps  Calories  SedentaryMinutes  LightlyActiveMinutes  \
# 0           13162      1985               728                   328
# 1           13162      1985               728                   328
# 2           13162      1985               728                   328
# 3           13162      1985               728                   328
# 4           13162      1985               728                   328
# ...           ...       ...               ...                   ...
# 12620        8064      1849               770                   137
# 12621        8064      1849               770                   137
# 12622        8064      1849               770                   137
# 12623        8064      1849               770                   137
# 12624        8064      1849               770                   137
#
#        FairlyActiveMinutes  VeryActiveMinutes  SedentaryActiveDistance  \
# 0                       13                 25                      0.0
# ...

# %%
print(df.duplicated().value_counts())
# Out:
# False    12503
# Name: count, dtype: int64

# %% [markdown]
# **Observation:**
#
#    *

# %% [markdown]
# **5.Check for null values in each column and handle them appropriately.**

# %%
print(df.isnull().sum())
# Out:
# TotalSteps                  0
# Calories                    0
# SedentaryMinutes            0
# LightlyActiveMinutes        0
# FairlyActiveMinutes         0
# VeryActiveMinutes           0
# SedentaryActiveDistance     0
# LightActiveDistance         0
# ModeratelyActiveDistance    0
# VeryActiveDistance          0
# TotalActiveMinutes          0
# TotalDistance               0
# ActivityDayName             0
# TotalMinutesAsleep          0
# TotalTimeInBed              0
# WeightKg                    0
# Heightm                     0
# BMI                         0
# dtype: int64

# %% [markdown]
# **Observation:**
#
#  * In this Dataset there is no null values are present

# %% [markdown]
# **6.Create new columns for:Total Distance,Total Minutes,and Total Active Minutes.**

# %%
datas=df.assign(TotalActiveMinutes=df['LightlyActiveMinutes']+df['FairlyActiveMinutes']+df['VeryActiveMinutes'])
datas
# Out:
#        TotalSteps  Calories  SedentaryMinutes  LightlyActiveMinutes  \
# 0           13162      1985               728                   328
# 1           13162      1985               728                   328
# 2           13162      1985               728                   328
# 3           13162      1985               728                   328
# 4           13162      1985               728                   328
# ...           ...       ...               ...                   ...
# 12620        8064      1849               770                   137
# 12621        8064      1849               770                   137
# 12622        8064      1849               770                   137
# 12623        8064      1849               770                   137
# 12624        8064      1849               770                   137
#
#        FairlyActiveMinutes  VeryActiveMinutes  SedentaryActiveDistance  \
# 0                       13                 25                      0.0
# ...

# %% [markdown]
# **Observation:**

# %% [markdown]
# **7.Drop Unnecessary columns from the Dataframe**

# %%
data=df.drop(['TotalTimeInBed','WeightKg','Heightm','BMI','TotalMinutesAsleep','ActivityDayName','TotalSteps','Calories','SedentaryMinutes'],inplace=True,axis=1)
data
# Out:
# C:\Users\ABINANDH SREEKUMAR\AppData\Local\Temp\ipykernel_13616\1658271992.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data=df.drop(['TotalTimeInBed','WeightKg','Heightm','BMI','TotalMinutesAsleep','ActivityDayName','TotalSteps','Calories','SedentaryMinutes'],inplace=True,axis=1)

# %% [markdown]
# **8.Rename columns in the DataFrame with meaningful names.**

# %%
data=df.rename(columns={'Calories':'CaloriesBurnt','TotalDistance':'TotalDistancekm','VeryActiveMinutes':'ActiveMinutes'})
data
# Out:
#        LightlyActiveMinutes  FairlyActiveMinutes  ActiveMinutes  \
# 0                       328                   13             25
# 1                       328                   13             25
# 2                       328                   13             25
# 3                       328                   13             25
# 4                       328                   13             25
# ...                     ...                  ...            ...
# 12620                   137                    1             23
# 12621                   137                    1             23
# 12622                   137                    1             23
# 12623                   137                    1             23
# 12624                   137                    1             23
#
#        SedentaryActiveDistance  LightActiveDistance  ModeratelyActiveDistance  \
# 0                          0.0                 6.06                      0.55
# ...

# %% [markdown]
# **9.Generate random values for an Age Group Column.**

# %%
age_groups=['10-20','25-40','50-65','70-100']
df['Age_Group']=np.random.choice(age_groups,size=len(df))
df['Age_Group']
# Out:
# C:\Users\ABINANDH SREEKUMAR\AppData\Local\Temp\ipykernel_13616\3216607659.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age_Group']=np.random.choice(age_groups,size=len(df))
# 0         50-65
# 1         25-40
# 2        70-100
# 3         50-65
# 4        70-100
#           ...
# 12620    70-100
# 12621    70-100
# 12622     10-20
# 12623     10-20
# 12624     50-65
# Name: Age_Group, Length: 12503, dtype: object

# %% [markdown]
# **Observation:**
#
#   * A new column Age_Group is successfully created in the dataframe.
#
#   * It contains 12503 entries same as the number of rows in the dataset.
#
#   * Each entry is randomly assigned one of the four specified categories:10-20,25-40,50-65 or
#
#     70-100.
#
#   * Because sampling is random,the distribution of counts will vary each time the code is
#
#     executed,but every value will always belong to one of these four groups.

# %% [markdown]
# **10.Generate random values for a Gender column.**

# %%
genders=['Male','Female']
df['Genders']=np.random.choice(genders,size=len(df))
df['Genders']
# Out:
# C:\Users\ABINANDH SREEKUMAR\AppData\Local\Temp\ipykernel_13616\1478316292.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Genders']=np.random.choice(genders,size=len(df))
# 0        Female
# 1        Female
# 2        Female
# 3          Male
# 4        Female
#           ...
# 12620    Female
# 12621    Female
# 12622      Male
# 12623      Male
# 12624    Female
# Name: Genders, Length: 12503, dtype: object

# %% [markdown]
# **Observation:**
#
#   * Here the new column named Genders has been added to the DataFrame.
#
#   * Each entry is randomly assigned either Male or Female.
#
#   * The actual counts of Male and Female will vary each time the code runs,because the values
#
#     are generated randomly.

# %% [markdown]
# **11.Convert the categorical columns(e.g.Gender,Age Group) in to categorical data types.**

# %%
df['Genders']=df['Genders'].astype('category')
df['Age_Group']=df['Age_Group'].astype('category')
print(df[['Genders','Age_Group']].dtypes)
# Out:
# Genders      category
# Age_Group    category
# dtype: object
# C:\Users\ABINANDH SREEKUMAR\AppData\Local\Temp\ipykernel_13616\1881533374.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Genders']=df['Genders'].astype('category')
# C:\Users\ABINANDH SREEKUMAR\AppData\Local\Temp\ipykernel_13616\1881533374.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age_Group']=df['Age_Group'].astype('category')

# %% [markdown]
# **12.Perform outlier detection on numeric features.**

# %%
numeric_col=df.select_dtypes(include=['int64','float64']).columns
for cols in numeric_col:
  
  Q1=df[cols].quantile(0.25)
  Q3=df[cols].quantile(0.75)
  IQR=Q3-Q1
  outliers = df[(df[cols] < Q1-1.5*IQR) | (df[cols] > Q3+1.5*IQR)]
  print(f"Column: {cols}")
  print(f"Outlier count: {len(outliers)}")
  print(outliers[cols].head())
# Out:
# Column: LightlyActiveMinutes
# Outlier count: 84
# 1677    513
# 1678    513
# 1679    513
# 1680    513
# 1681    513
# Name: LightlyActiveMinutes, dtype: int64
# Column: FairlyActiveMinutes
# Outlier count: 682
# 26    51
# 27    51
# 28    51
# 29    51
# 30    51
# Name: FairlyActiveMinutes, dtype: int64
# Column: VeryActiveMinutes
# Outlier count: 885
# 260    86
# 261    86
# 262    86
# 263    86
# 264    86
# Name: VeryActiveMinutes, dtype: int64
# Column: SedentaryActiveDistance
# Outlier count: 1087
# 130    0.01
# 131    0.01
# 132    0.01
# 133    0.01
# 134    0.01
# Name: SedentaryActiveDistance, dtype: float64
# Column: LightActiveDistance
# Outlier count: 75
# 1677    10.3
# 1678    10.3
# 1679    10.3
# 1680    10.3
# 1681    10.3
# Name: LightActiveDistance, dtype: float64
# Column: ModeratelyActiveDistance
# Outlier count: 800
# 26    2.3
# 27    2.3
# 28    2.3
# 29    2.3
# 30    2.3
# Name: ModeratelyActiveDistance, dtype: float64
# Column: VeryActiveDistance
# ...

# %% [markdown]
# **13.Remove or treat the outliers appropriately**

# %%
Q1=df[cols].quantile(0.25)
Q3=df[cols].quantile(0.75)
IQR=Q3-Q1
filtered_df=df[(df[cols]>=Q1-1.5*IQR)&(df[cols]<=Q3+1.5*IQR)]
print(filtered_df.shape)
# Out:
# (12192, 11)

# %% [markdown]
# **14.Plot distribution histograms for all numeric features.**

# %%
df[cols].hist(figsize=(15,10),bins=30,edgecolor='black')
plt.title("Distribution  of Numeric Features")
plt.tight_layout()
plt.show()

# %% [markdown]
# **15.Visualize Total Active Minutes by Day of the week using boxplot.**

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df,x='ActivityDayName ',y='TotalActiveMinutes ',palette='coolwarm')
plt.title("Total Active Minutes by Day of the Week")
plt.xlabel('Day of the week')
plt.ylabel('Total Active Minutes')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 2
#       1 plt.figure(figsize=(10,6))
# ----> 2 sns.boxplot(data=df,x='ActivityDayName ',y='TotalActiveMinutes ',palette='coolwarm')
#       3 plt.title("Total Active Minutes by Day of the Week")
#       4 plt.xlabel('Day of the week')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\seaborn\categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)   1594     legend="auto", ax=None, **kwargs
#    1595 ):
# ...

# %%
print('ActivityDayName' in df.columns)
# Out:
# False
